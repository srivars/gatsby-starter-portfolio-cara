# %% [markdown]
# <a href="https://colab.research.google.com/github/srivars/gatsby-starter-portfolio-cara/blob/main/pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/dog.jpg')

# %%
#cv2.imshow("dog.jpg", image)
#cv2.waitKey(0)
#image = cv2.imread("/content/runnnn.jfif")
lane_image = np.copy(image)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FAE715EA690>
# -1

# %%
inverted_image = 255 - gray_image

# %%
cv2_imshow(inverted_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FAE715F7390>
# -1

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FAE715E3C10>
# -1
